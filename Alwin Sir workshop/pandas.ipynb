# %%
import pandas as pd

# %%
students = {
    "Name":['abhi','Joffin','hiran','jaise'],
    "Age" :['22','33','34','43']
}
print(students)
# Out:
# {'Name': ['abhi', 'Joffin', 'hiran', 'jaise'], 'Age': ['22', '33', '34', '43']}

# %%
df = pd.DataFrame(students)

# %%
#print(df.head())
print(df.tail())
# Out:
#      Name Age
# 0    abhi  22
# 1  Joffin  33
# 2   hiran  34
# 3   jaise  43

# %%
df
# Out:
#      Name Age
# 0    abhi  22
# 1  Joffin  33
# 2   hiran  34
# 3   jaise  43

# %%
df = pd.read_excel("C:\\Users\\JOHN GEORGE THATTIL\\Downloads\\Training Institute Datas.xlsx")

# %%
df.head()
# Out:
#   Training Institutes Data           Unnamed: 1  \
# 0                      NaN                  NaN
# 1                       SN                 DATE
# 2                        1  2023-08-05 00:00:00
# 3                      NaN                  NaN
# 4                        2  2023-08-05 00:00:00
#
#                                    Unnamed: 2  \
# 0                                         NaN
# 1                                        NAME
# 2                             WINSTUD ACADEMY
# 3                                         NaN
# 4  National Institute for Technical Education
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 1                                         DEPARTMENT
# 2  Accounts & Management,Teacher Training,\n Engi...
# 3                                                NaN
# 4  Computerised fashion Designing Course,\n Vanit...
#
#                                           Unnamed: 4  \
# ...

# %%
pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
df.head()
# Out:
#   Training Institutes Data           Unnamed: 1  \
# 0                      NaN                  NaN
# 1                       SN                 DATE
# 2                        1  2023-08-05 00:00:00
# 3                      NaN                  NaN
# 4                        2  2023-08-05 00:00:00
#
#                                    Unnamed: 2  \
# 0                                         NaN
# 1                                        NAME
# 2                             WINSTUD ACADEMY
# 3                                         NaN
# 4  National Institute for Technical Education
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 1                                         DEPARTMENT
# 2  Accounts & Management,Teacher Training,\n Engi...
# 3                                                NaN
# 4  Computerised fashion Designing Course,\n Vanit...
#
#                                           Unnamed: 4  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 13
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.8.0-cp311-cp311-win_amd64.whl (7.6 MB)
# ...
#   Using cached contourpy-1.1.1-cp311-cp311-win_amd64.whl (480 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#   Using cached fonttools-4.43.1-cp311-cp311-win_amd64.whl (2.1 MB)
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
# ...
#                                               0.0/2.6 MB ? eta -:--:--
#                                               0.0/2.6 MB ? eta -:--:--
#                                               0.0/2.6 MB ? eta -:--:--
#                                               0.0/2.6 MB 281.8 kB/s eta 0:00:10
#      -                                        0.1/2.6 MB 459.5 kB/s eta 0:00:06
#      -                                        0.1/2.6 MB 476.3 kB/s eta 0:00:06
#      -                                        0.1/2.6 MB 467.6 kB/s eta 0:00:06
#      --                                       0.2/2.6 MB 517.2 kB/s eta 0:00:05
# ...

# %%
import pandas as pd
df=pd.read_csv("IRIS.csv")
print(df.to_string())
#df.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
df['sepal_length'].hist()
# Out:
# <Axes: >

# %% [markdown]
# write a python program with the following specifications ?
# There will be a function_name, create dataset which will take a dictionary,filename & no of rows as arguments ?
# The dictionary has having the following structure
# {
#     "columnname" [domain of values]
# }
# Your function will select random values for each of the domains & create a row  for you. The number of rows thath have to be created is the parameter.
# Save the file with the required number of rows '
# Load this dataset using panda and display basic information , which includes the shape, size , datatype....?

# %%
import random
def create_dataset(data_dict,file_name, num_rows):
    pass
dict = {
         "col_name": ["val1","val2",....],
         "col_name":["val1","val2",.....],
         "col_name":["val1","val2",.....],
       }

create_dataset(dict,"data.csv",50)7
    

#user input rows = int(input("Enter the no of rows required:"))
# Out:
#   Cell In[1], line 5
#     "col_name": ["val1","val2",....],
#                                    ^
# SyntaxError: invalid syntax
